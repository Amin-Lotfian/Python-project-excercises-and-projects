# %% [markdown]
# <a href="https://colab.research.google.com/github/Amin-Lotfian/Python-project-excercises-and-projects/blob/main/20_Histograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
# !pip install datasets
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_Ir = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'Ireland')].copy()
df_DA_Ir = df_DA_Ir.dropna(subset=['salary_year_avg'])

# %%
df_DA_Ir['salary_year_avg'].plot(kind='hist', bins=30, edgecolor='black')
plt.xlim(0, 250000)


#these two lines are just for axis:
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))


plt.title('Distribution of United States Data Analyst Yearly Salaries')
plt.xlabel('Yearly Salary')
plt.ylabel('Number of Jobs')
plt.show()

# %%
help(plt.gca)
# Out:
# Help on function gca in module matplotlib.pyplot:
#
# gca()
#     Get the current Axes.
#
#     If there is currently no Axes on this Figure, a new one is created
#     using `.Figure.add_subplot`.  (To test whether there is currently an
#     Axes on a Figure, check whether ``figure.axes`` is empty.  To test
#     whether there is currently a Figure on the pyplot figure stack, check
#     whether `.pyplot.get_fignums()` is empty.)

# %%
help(plt.gca().xaxis.set_major_formatter)
# Out:
# Help on method set_major_formatter in module matplotlib.axis:
#
# set_major_formatter(formatter) method of matplotlib.axis.XAxis instance
#     Set the formatter of the major ticker.
#
#     In addition to a `~matplotlib.ticker.Formatter` instance,
#     this also accepts a ``str`` or function.
#
#     For a ``str`` a `~matplotlib.ticker.StrMethodFormatter` is used.
#     The field used for the value must be labeled ``'x'`` and the field used
#     for the position must be labeled ``'pos'``.
#     See the  `~matplotlib.ticker.StrMethodFormatter` documentation for
#     more information.
#
#     For a function, a `~matplotlib.ticker.FuncFormatter` is used.
#     The function must take two inputs (a tick value ``x`` and a
#     position ``pos``), and return a string containing the corresponding
#     tick label.
#     See the  `~matplotlib.ticker.FuncFormatter` documentation for
#     more information.
#
#     Parameters
#     ----------
# ...
