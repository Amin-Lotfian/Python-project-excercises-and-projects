# %% [markdown]
# <a href="https://colab.research.google.com/github/Amin-Lotfian/Python-project-excercises-and-projects/blob/main/14_Pandas_Merge(horizontal)_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## size includes NaN values in the count, while count will only count non-missing values. In most cases, count is the preferred method when you want a more accurate count of valid, non-missing data points.

# %% [markdown]
# ## Pandas Merge DataFrames

# %% [markdown]
# Load data.

# %%
# Importing Libraries
# !pip install datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
job_data = {
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Software Engineer', 'Product Manager', 'Marketing Director', 'HR Manager'],
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'job_location': ['Mountain View, CA', 'Redmond, WA', 'Cupertino, CA', 'Beaverton, OR', 'Seattle, WA']
}

company_data = {
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'industry': ['Technology', 'Technology', 'Technology', 'Apparel', 'Food & Beverage'],
    'company_size': ['100,000+', '100,000+', '100,000+', '75,000+', '346,000+']
}


df_jobs = pd.DataFrame(job_data)
df_companies = pd.DataFrame(company_data)

# %%
df_jobs
# Out:
#    job_id           job_title company_name       job_location
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA

# %%
df_companies
# Out:
#   company_name         industry company_size
# 0       Google       Technology     100,000+
# 1    Microsoft       Technology     100,000+
# 2        Apple       Technology     100,000+
# 3         Nike          Apparel      75,000+
# 4    Starbucks  Food & Beverage     346,000+

# %%
# Merge the two datasets on the 'job_id' column
df_job_company = df_jobs.merge(df_companies, on='company_name')

df_job_company
# Out:
#    job_id           job_title company_name       job_location  \
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA
#
#           industry company_size
# 0       Technology     100,000+
# 1       Technology     100,000+
# 2       Technology     100,000+
# 3          Apparel      75,000+
# 4  Food & Beverage     346,000+

# %% [markdown]
# ### Example 2
#
# The data we have is only for data science job postings, but what if we wanted to combine insights with other job industries?
#
# Recall the pivot we previously made:

# %%
import calendar
df_US = df[df['job_country'] == 'United States'].copy()
df_US['job_posted_month_no'] = df_US['job_posted_date'].dt.month
df_US_pivot = df_US.pivot_table(index='job_posted_month_no', columns='job_title_short', aggfunc='size')


# Reset the index to make 'job_posted_month_no' a column again
df_US_pivot = df_US_pivot.reset_index()
# Now you can access 'job_posted_month_no' as a column
df_US_pivot['job_posted_month'] = df_US_pivot['job_posted_month_no'].apply(lambda x: calendar.month_name[x])

df_US_pivot = df_US_pivot.set_index('job_posted_month')
df_US_pivot = df_US_pivot.drop(columns='job_posted_month_no')
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212

# %% [markdown]
# Let's make some fake data for this.

# %%
import random


# Define job titles
job_titles = ['Front-End Developer', 'Back-End Developer', 'Full-Stack Developer', 'UI/UX Designer']

# Define months
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Define ranges for random data
ranges = {
    'Front-End Developer': (11000, 15000),
    'Back-End Developer': (8000, 10000),
    'Full-Stack Developer': (5000, 7500),
    'UI/UX Designer': (4000, 5000)
}

# Generate random data
data = {}
for job_title in job_titles:
    data[job_title] = [random.randint(ranges[job_title][0], ranges[job_title][1]) for _ in months]

# Create DataFrame
df_US_software_pivot = pd.DataFrame(data, index=months)
df_US_software_pivot.index.name = "job_posted_month"

df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         11966                9879
# February                        12242                8592
# March                           11422                9639
# April                           13954                9567
# May                             12622                8120
# June                            12961                8454
# July                            11634                9065
# August                          11369                9099
# September                       11272                8737
# October                         11081                8566
# November                        12644                9596
# December                        13250                8353
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5434            4865
# February                          6072            4620
# March                             5878            4345
# April                             5105            4687
# May                               6066            4397
# June                              6113            4518
# July                              5792            4254
# August                            5675            4182
# September                         6269            4253
# October                           6186            4484
# November                          6525            4286
# December                          5355            4091

# %% [markdown]
# Alternatively, we can just load the data:

# %%
df_US_software_pivot = pd.read_csv('https://lukeb.co/software_csv', index_col='job_posted_month')

df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %% [markdown]
# Well we can combine these using merge:

# %%
df_US_merged = df_US_pivot.merge(df_US_software_pivot, on='job_posted_month')
df_US_merged
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
#                   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
#                   Senior Data Scientist  Software Engineer  \
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212
#
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %% [markdown]
# And now we can plot it!

# %%
# find top 5 job titles (columns) in df_US_merged
top_5 = df_US_merged.sum().sort_values(ascending=False).head(5).index.tolist()
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'Data Analyst',
#  'Data Scientist']

# %%
df_US_merged[top_5].plot(kind='line')
plt.title('Monthly Job Postings for Top Tech Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()

# %% [markdown]
# ### Example 3
#
# Now looking at our dataset. Let's create two DataFrames.
# * The first one will get the count of Data Analyst jobs by month.
# * The second one will (similarly) get the count of Senior Data Analyst jobs by month.
#
# Finally, we will merge these two DataFrames to easily compare the demand for Data Analyst vs Senior Data Analyst jobs.

# %% [markdown]
# 1. Create a new DataFrame that only gets Data Analyst jobs, creates a column for the month, and get the job postings by month.

# %%
## Filter for Data Analysts
df_DA = df[(df['job_title_short'] == 'Data Analyst')].copy()

## Create a column for month
df_DA['month'] = df_DA['job_posted_date'].dt.month

## Pivot table to count job postings by month
df_DA_pivot = df_DA.pivot_table(index='month', aggfunc='count')['job_title_short']

## Print the pivot table
df_DA_pivot
# Out:
# month
# 1     23585
# 2     16558
# 3     16243
# 4     15514
# 5     13423
# 6     16008
# 7     16095
# 8     18628
# 9     14969
# 10    16239
# 11    15230
# 12    13583
# Name: job_title_short, dtype: int64

# %% [markdown]
# 2. Create a new DataFrame that only gets Senior Data Analyst jobs, creates a column for the month, and get the job postings by month.

# %%
## Filter for Senior Data Analysts
df_SDA = df[(df['job_title_short'] == 'Senior Data Analyst')].copy()

## Create a column for month
df_SDA['month'] = df_SDA['job_posted_date'].dt.month

## Pivot table to count job postings by month
df_SDA_pivot = df_SDA.pivot_table(index='month', aggfunc='count')['job_title_short']

## Print the pivot table
df_SDA_pivot
# Out:
# month
# 1     3696
# 2     2713
# 3     2454
# 4     2351
# 5     1925
# 6     2319
# 7     2380
# 8     2951
# 9     2194
# 10    2317
# 11    2117
# 12    1799
# Name: job_title_short, dtype: int64

# %% [markdown]
# 3. Finally, we'll merge the two pivot tables together.

# %%
## Merge the two pivot tables
merged_DA_pivot = pd.merge(df_DA_pivot, df_SDA_pivot, how='outer', left_index=True, right_index=True)
merged_DA_pivot.columns = ['DA_count', 'SDA_count']
merged_DA_pivot
# Out:
#        DA_count  SDA_count
# month
# 1         23585       3696
# 2         16558       2713
# 3         16243       2454
# 4         15514       2351
# 5         13423       1925
# 6         16008       2319
# 7         16095       2380
# 8         18628       2951
# 9         14969       2194
# 10        16239       2317
# 11        15230       2117
# 12        13583       1799
