# %% [markdown]
# <a href="https://colab.research.google.com/github/Amin-Lotfian/Python-project-excercises-and-projects/blob/main/12_index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
# !pip install datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = 'job_index'
df.index.name
# Out:
# 'job_index'

# %%
df
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# df_ireland = df[df['job_country'] == 'Ireland']
# print(id(df_ireland))
# print(id(df))

# %%
df_ireland.head()
# Out:
#                  job_title_short  \
# job_index
# 33                 Data Engineer
# 56         Senior Data Scientist
# 63                 Data Engineer
# 306         Senior Data Engineer
# 369                 Data Analyst
#
#                                                    job_title  \
# job_index
# 33                                             Data Engineer
# 56                           Principal Statistical Scientist
# 63                                  Full Stack Data Engineer
# 306        Senior Data Engineer - Dublin - Permanent - Hy...
# 369                                   Principal Data Analyst
#
#                         job_location                   job_via  \
# job_index
# 33         County Westmeath, Ireland                via Indeed
# 56                          Anywhere              via LinkedIn
# 63                 Limerick, Ireland           via Trabajo.org
# 306                  Dublin, Ireland  via SimplyHired, Ireland
# ...

# %%
df_ireland.reset_index(inplace=True)
df_ireland.head()
# Out:
#    job_index        job_title_short  \
# 0         33          Data Engineer
# 1         56  Senior Data Scientist
# 2         63          Data Engineer
# 3        306   Senior Data Engineer
# 4        369           Data Analyst
#
#                                            job_title  \
# 0                                      Data Engineer
# 1                    Principal Statistical Scientist
# 2                           Full Stack Data Engineer
# 3  Senior Data Engineer - Dublin - Permanent - Hy...
# 4                             Principal Data Analyst
#
#                 job_location                   job_via job_schedule_type  \
# 0  County Westmeath, Ireland                via Indeed         Full-time
# 1                   Anywhere              via LinkedIn         Full-time
# 2          Limerick, Ireland           via Trabajo.org         Full-time
# 3            Dublin, Ireland  via SimplyHired, Ireland         Full-time
# ...

# %%
df_ireland.set_index('job_location', inplace=True)
df_ireland.head()
# Out:
#                            job_index        job_title_short  \
# job_location
# County Westmeath, Ireland         33          Data Engineer
# Anywhere                          56  Senior Data Scientist
# Limerick, Ireland                 63          Data Engineer
# Dublin, Ireland                  306   Senior Data Engineer
# Dublin, Ireland                  369           Data Analyst
#
#                                                                    job_title  \
# job_location
# County Westmeath, Ireland                                      Data Engineer
# Anywhere                                     Principal Statistical Scientist
# Limerick, Ireland                                   Full Stack Data Engineer
# Dublin, Ireland            Senior Data Engineer - Dublin - Permanent - Hy...
# Dublin, Ireland                                       Principal Data Analyst
#
#                                             job_via job_schedule_type  \
# job_location
# ...

# %%
df_ireland.sort_index(inplace=True)
df_ireland.head()
# Out:
# <ipython-input-11-69deb2a320e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ireland.sort_index(inplace=True)
#               job_index       job_title_short  \
# job_location
# Anywhere         380919         Data Engineer
# Anywhere         541700        Data Scientist
# Anywhere          70641      Business Analyst
# Anywhere         541483  Senior Data Engineer
# Anywhere         237629         Data Engineer
#
#                                                       job_title  \
# job_location
# Anywhere               Database Engineer (SQL/NoSQL) - Contract
# Anywhere      Data Scientist / AI Engineer / AI Data Enginee...
# Anywhere                                     Operations Analyst
# Anywhere        Senior Data Infra Engineer II (Remote /Ireland)
# ...
